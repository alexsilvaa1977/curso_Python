# %% [markdown]
# # Aula 1 — Classes, objetos e atributos (exemplos práticos)

# %%
class Pessoa:
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

ana = Pessoa("Ana", 28)
bruno = Pessoa("Bruno", 34)

print(ana.nome, ana.idade)
print(bruno.nome, bruno.idade)

# %% [markdown]
# ## Experimento guiado
#
# Crie uma terceira `Pessoa` com seus próprios dados e imprima seus atributos.

# %% [markdown]
# ## Métodos

# %%
class Pessoa:
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

    def apresentar(self):
        return f"Oi, eu sou {self.nome} e tenho {self.idade} anos."

    def fazer_aniversario(self):
        self.idade += 1

ana = Pessoa("Ana", 28)
print(ana.apresentar())
ana.fazer_aniversario()
print(ana.idade)

# %% [markdown]
# ## Atributos de classe vs. de instância

# %%
class Pessoa:
    especie = "Homo sapiens"

    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

ana = Pessoa("Ana", 28)
bruno = Pessoa("Bruno", 34)

print(ana.especie, bruno.especie)
print(Pessoa.especie)

# %% [markdown]
# ## Contando instâncias com atributo de classe

# %%
class Pessoa:
    total_criadas = 0

    def __init__(self, nome):
        self.nome = nome
        Pessoa.total_criadas += 1

Pessoa("Ana")
Pessoa("Bruno")
Pessoa("Carla")
print(Pessoa.total_criadas)

# %% [markdown]
# ## O erro clássico: esquecer `self.`

# %%
class ContaSemBug:
    def __init__(self, saldo_inicial):
        self.saldo = saldo_inicial

class ContaComBug:
    def __init__(self, saldo_inicial):
        saldo = saldo_inicial  # faltou "self." -- não é salvo no objeto

conta_ok = ContaSemBug(100)
print("com self:", conta_ok.saldo)

conta_bug = ContaComBug(100)
try:
    print("sem self:", conta_bug.saldo)
except AttributeError as erro:
    print("Erro esperado:", erro)

# %% [markdown]
# ## Mini-desafio resolvido
#
# **Desafio:** classe `ContaBancaria` com depósito e saque simples.

# %%
class ContaBancaria:
    def __init__(self, titular, saldo_inicial=0):
        self.titular = titular
        self.saldo = saldo_inicial

    def depositar(self, valor):
        self.saldo += valor

    def sacar(self, valor):
        if valor > self.saldo:
            print("Saldo insuficiente")
        else:
            self.saldo -= valor

conta = ContaBancaria("Ana", 100)
conta.depositar(50)
conta.sacar(30)
print(conta.titular, conta.saldo)

conta.sacar(1000)
